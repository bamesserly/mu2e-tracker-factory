# %% [markdown]
# # Combine straw info into a couple of csvs
# Export the csvs so you can import them into another sheet and do analysis
# two sources of info:
# 1. leak rate raw data files: tens of thousands of txt files -- more than one for each straw
# 2. database, which contains batch, ppg, and panel info for most straws since 173
#
# Do a little processing of (1) here: re-extract the leak rates and combine them into a df.

# %%
import pandas as pd
from pathlib import Path
import sys
sys.path.append('/Users/Ben/Projects/mu2e-tracker-factory/')

# %% [markdown]
# ## 1. Leak Rate of every straw
# - Loop all 40,000 raw data files and fit the data to get a leak rate
# - Takes ~minutes
# - End result: a data frame with columns: straw, raw data file, fit value, fit error, fit status
# - Minimal cleaning: remove UNKNOWN, FAILED fits, and unphysical leaks < 0.

# %%
# indir, location of raw data
#from guis.common.getresources import GetProjectPaths
#indir = GetProjectPaths()["strawleakdata"] / "raw_data"
indir = Path("/Users/Ben/Projects/mu2e-tracker-factory/data/all_straw_leak_data") # collected ALL the data
print(indir)
print(indir.is_dir())
# Out:
# /Users/Ben/Projects/mu2e-tracker-factory/data/all_straw_leak_data
# True

# %%
# fitting function
from calc_straw_leak import refit, NotEnoughData

# %%
# one row for each file – many rows for one straw are allowed.
leak_data = []
for raw_data_file in indir.rglob("*.txt"):
    straw = str(raw_data_file.name)[2:7]
    
    #if straw != "23842":
    #    continue
        
    try:
        straw = int(straw)
    except ValueError:
        print("BAD FILE (FILENAME)", raw_data_file.name)
        continue

    try:
        leak_rate, leak_rate_err, leak_status, chamber = refit(raw_data_file)
    except NotEnoughData:
        continue
    except IndexError as e:
        print("BAD FILE (INDEX)", e, raw_data_file.name)
    except ValueError as e:
        print("BAD FILE (VALUE)", raw_data_file.name)
        #print(e)
        continue
        
    leak_data.append(
        {
            'straw':straw,
            'leak_data_file':str(raw_data_file.name),
            'rate': leak_rate,
            'rate_err':leak_rate_err,
            #'status':leak_status.value,
            'status':leak_status,
            'chamber':chamber,
        }
    )
# Out:
# BAD FILE (FILENAME) bkg43_2_chamber43_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) err5_105_chamber19_2018_04_23_rawdata.txt
# BAD FILE (FILENAME) GtBent14_chamber39_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) STO2333_chamber14_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) Al10_chamber14_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg26_2_chamber26_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) GtBent09_chamber9_2018_04_10_rawdata.txt
# BAD FILE (FILENAME) bkg10_2_chamber10_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) GtBent21_chamber21_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) al12_chamber11_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) GtBent13_chamber38_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) STO2334_chamber15_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) err1_045_chamber27_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) bkg41_chamber41_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent02_chamber2_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) err5_087_chamber1_2018_04_10_rawdata.txt
# BAD FILE (FILENAME) err5_088_chamber2_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) empty28_rawdata.txt
# BAD FILE (FILENAME) Retest07_chamber6_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) err4_081_chamber30_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) empty34_rawdata.txt
# BAD FILE (FILENAME) GtBent13_chamber13_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) GtBent22_chamber22_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) Al62_chamber12_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) empty44_rawdata.txt
# BAD FILE (FILENAME) err2_054_chamber28_2018_04_20_rawdata.txt
# BAD FILE (FILENAME) GtBent10_chamber35_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) Example1_chamber13_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) Retest07_chamber0_2018_04_19_rawdata.txt
# BAD FILE (FILENAME) al22_chamber21_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) GtBent11_chamber11_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) GtBent01_chamber1_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) err1_048_chamber27_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) Retest02_chamber1_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) err1_057_chamber27_2018_04_27_rawdata.txt
# BAD FILE (FILENAME) bkg37_2_chamber37_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) err5_095_chamber9_2018_04_16_rawdata.txt
# BAD FILE (FILENAME) GtBent07_chamber7_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) Retest01_chamber0_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) err5_063_chamber43_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) al21_chamber20_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) empty5_rawdata.txt
# BAD FILE (FILENAME) Al53_chamber4_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) empty21_rawdata.txt
# BAD FILE (FILENAME) GtBent15_chamber15_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) err4_077_chamber30_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) err2_043_chamber28_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) STO2144_chamber16_2018_08_21_rawdata.txt
# BAD FILE (FILENAME) err2_051_chamber28_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) err1_047_chamber27_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) bkg21_chamber21_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) bkg1_2_chamber1_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) test30_chamber30_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) Al20_chamber3_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg25_3_chamber25_2018_03_28_rawdata.txt
# BAD FILE (FILENAME) err5_109_chamber23_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) err5_107_chamber21_2018_04_24_rawdata.txt
# BAD FILE (FILENAME) err3_057_chamber25_2018_04_26_rawdata.txt
# BAD FILE (FILENAME) err5_100_chamber14_2018_04_19_rawdata.txt
# BAD FILE (FILENAME) testing3_chamber48_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) al11_chamber10_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) bkg34_chamber34_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err2_062_chamber28_2018_05_03_rawdata.txt
# BAD FILE (FILENAME) testme1_ch0_2018_03_22_rawdata.txt
# BAD FILE (FILENAME) bkg37_4_chamber37_2018_03_30_rawdata.txt
# BAD FILE (FILENAME) test0409_chamber30_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) Al65_chamber14_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) GtBent04_chamber4_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) err4_084_chamber30_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) err2_050_chamber28_2018_04_12_rawdata.txt
# BAD FILE (FILENAME) err4_070_chamber49_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) bkg11_chamber11_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) empty13_rawdata.txt
# BAD FILE (FILENAME) Retest03_chamber0_2018_04_20_rawdata.txt
# BAD FILE (FILENAME) err4_097_chamber10_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) STO2328_chamber9_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) GtBent09_chamber9_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) al15_chamber14_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) Al23_chamber6_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) err4_100_chamber13_2018_04_19_rawdata.txt
# BAD FILE (FILENAME) err4_098_chamber11_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) bkg30_chamber30_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err3_050_chamber25_2018_04_12_rawdata.txt
# BAD FILE (FILENAME) bkg6_chamber6_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err5_091_chamber5_2018_04_12_rawdata.txt
# BAD FILE (FILENAME) empty24_rawdata.txt
# BAD FILE (FILENAME) err4_071_chamber25_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) bkg36_4_chamber36_2018_03_30_rawdata.txt
# BAD FILE (FILENAME) GtBent02_chamber2_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) empty0_rawdata.txt
# BAD FILE (FILENAME) GtBent19_chamber19_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) test_chamber10_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) bkg15_chamber15_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent04_chamber4_2018_04_10_rawdata.txt
# BAD FILE (FILENAME) err5_106_chamber20_2018_04_23_rawdata.txt
# BAD FILE (FILENAME) err4_093_chamber6_2018_04_12_rawdata.txt
# BAD FILE (FILENAME) err3_062_chamber25_2018_05_03_rawdata.txt
# BAD FILE (FILENAME) GtBent21_chamber21_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) Retest03_chamber0_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) err3_051_chamber25_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) empty16_rawdata.txt
# BAD FILE (FILENAME) err5_067_chamber47_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) err3_043_chamber25_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) Al50_chamber1_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) ,P,.txt
# BAD FILE (FILENAME) empty38_rawdata.txt
# BAD FILE (FILENAME) Al69_chamber19_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg25_chamber25_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) bkg0_2_chamber0_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) empty48_rawdata.txt
# BAD FILE (FILENAME) Retest07_chamber1_2018_04_16_rawdata.txt
# BAD FILE (FILENAME) Al55_chamber6_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) GtBent18_chamber18_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) ._chamber24_2018_06_05_rawdata.txt
# BAD FILE (FILENAME) GtBent15_chamber15_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) Retest04_chamber3_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) Al56_chamber7_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg36_2_chamber36_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) Al66_chamber16_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) err5_083_chamber31_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) sm_1in_chamber27_2018_04_16_rawdata.txt
# BAD FILE (FILENAME) Al18_chamber5_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) err3_054_chamber25_2018_04_20_rawdata.txt
# BAD FILE (FILENAME) empty9_rawdata.txt
# BAD FILE (FILENAME) err3_060_chamber25_2018_05_01_rawdata.txt
# BAD FILE (FILENAME) err5_068_chamber48_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) bkg28_3_chamber28_2018_03_28_rawdata.txt
# BAD FILE (FILENAME) err5_111_chamber0_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) al16_chamber15_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) Al14_chamber10_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) err4_074_chamber28_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) GtBent04_chamber4_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) GtBent16_chamber16_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) bkg0_chamber0_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent09_chamber9_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) err5_096_chamber10_2018_04_16_rawdata.txt
# BAD FILE (FILENAME) bkg11_2_chamber11_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) err1_049_chamber27_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) err5_098_chamber12_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) Al13_chamber11_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) GtBent01_chamber1_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) err4_073_chamber29_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) empty41_rawdata.txt
# BAD FILE (FILENAME) GtBent05_chamber5_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) Al72_chamber0_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg45_chamber45_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) bkg42_2_chamber42_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) empty31_rawdata.txt
# BAD FILE (FILENAME) err1_053_chamber27_2018_04_19_rawdata.txt
# BAD FILE (FILENAME) STO2330_chamber11_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) err4_064_chamber43_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) empty42_rawdata.txt
# BAD FILE (FILENAME) bkg49_2_chamber49_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) err4_068_chamber47_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) err5_071_chamber27_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) empty32_rawdata.txt
# BAD FILE (FILENAME) testing5_chamber12_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) 01776_chamber9_2018_08_22_rawdata.txt
# BAD FILE (FILENAME) err5_077_chamber31_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) GtBent04_chamber4_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) err1_044_chamber27_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) Bent13_chamber38_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) bkg22_chamber22_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err4_063_chamber42_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) Al2_chamber23_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) GtBent16_chamber16_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) test_chamber16_2018_04_19_rawdata.txt
# BAD FILE (FILENAME) err2_060_chamber28_2018_04_30_rawdata.txt
# BAD FILE (FILENAME) bkg32_3_chamber32_2018_03_28_rawdata.txt
# BAD FILE (FILENAME) bkg37_chamber37_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent07_chamber7_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) err5_097_chamber11_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) STO2338_chamber19_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) err4_094_chamber7_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) err2_046_chamber28_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) err5_084_chamber31_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) Al5_chamber19_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg12_chamber12_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err4_109_chamber22_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) Example1_chamber20_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) err4_107_chamber20_2018_04_24_rawdata.txt
# BAD FILE (FILENAME) STO2323_chamber4_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) err4_106_chamber19_2018_04_23_rawdata.txt
# BAD FILE (FILENAME) err2_056_chamber28_2018_04_24_rawdata.txt
# BAD FILE (FILENAME) GtBent22_chamber22_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) bkg45_2_chamber45_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) bkg20_2_chamber20_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) testing8_chamber45_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) bkg8_chamber8_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent01_chamber1_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) Al6_chamber18_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg16_2_chamber16_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) testing_ch28_2018_03_09_rawdata.txt
# BAD FILE (FILENAME) empty15_rawdata.txt
# BAD FILE (FILENAME) _chamber15_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) Retest03_chamber3_2018_04_23_rawdata.txt
# BAD FILE (FILENAME) bkg42_chamber42_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err1_055_chamber27_2018_04_23_rawdata.txt
# BAD FILE (FILENAME) bkg38_chamber38_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err4_105_chamber18_2018_04_23_rawdata.txt
# BAD FILE (FILENAME) err4_089_chamber2_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) GtBent12_chamber12_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) err2_057_chamber28_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) GtBent19_chamber19_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) empty3_rawdata.txt
# BAD FILE (FILENAME) err2_063_chamber28_2018_05_04_rawdata.txt
# BAD FILE (FILENAME) GtBent10_chamber10_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) Al91_chamber15_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) Al61_chamber11_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) GtBent21_chamber21_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) bkg2_2_chamber2_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) 1525_chamber21_2018_06_27_rawdata.txt
# BAD FILE (FILENAME) testing9_chamber20_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) _chamber1_2018_07_13_rawdata.txt
# BAD FILE (FILENAME) GtBent02_chamber2_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) Retest03_chamber1_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) err4_111_chamber24_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) nnnnn_chamber0_2018_07_25_rawdata.txt
# BAD FILE (FILENAME) Al1_chamber22_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) empty27_rawdata.txt
# BAD FILE (FILENAME) err5_081_chamber31_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) err1_060_chamber27_2018_05_03_rawdata.txt
# BAD FILE (FILENAME) bkg29_chamber29_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent12_chamber12_2018_04_10_rawdata.txt
# BAD FILE (FILENAME) bkg3_2_chamber3_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) al3_chamber2_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) GtBent14_chamber14_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) Retest05_chamber3_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) bkg36_3_chamber36_2018_03_29_rawdata.txt
# BAD FILE (FILENAME) Retest03_chamber0_2018_04_23_rawdata.txt
# BAD FILE (FILENAME) empty10_rawdata.txt
# BAD FILE (FILENAME) GtBent16_chamber16_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) err4_090_chamber3_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) al6_chamber5_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) err3_063_chamber25_2018_05_04_rawdata.txt
# BAD FILE (FILENAME) err4_083_chamber30_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) Al111_chamber21_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) err2_058_chamber28_2018_04_26_rawdata.txt
# BAD FILE (FILENAME) bkg19_chamber19_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent02_chamber2_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) empty22_rawdata.txt
# BAD FILE (FILENAME) GtBent15_chamber15_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) err1_059_chamber27_2018_05_01_rawdata.txt
# BAD FILE (FILENAME) GtBent15_chamber15_2018_04_09_rawdata-Copy.txt
# BAD FILE (FILENAME) bkg26_3_chamber26_2018_03_30_rawdata.txt
# BAD FILE (FILENAME) err5_108_chamber22_2018_04_24_rawdata.txt
# BAD FILE (FILENAME) GtBent07_chamber7_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) bkg17_2_chamber17_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) err1_063_chamber27_2018_05_10_rawdata.txt
# BAD FILE (FILENAME) bkg21_2_chamber21_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) al19_chamber18_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) STO2326_chamber7_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) err2_059_chamber28_2018_04_27_rawdata.txt
# BAD FILE (FILENAME) empty6_rawdata.txt
# BAD FILE (FILENAME) bkg3_chamber3_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) bkg46_chamber46_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err5_074_chamber29_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) err1_052_chamber27_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) Al15_chamber9_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) Al71_chamber21_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg44_2_chamber44_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) empty19_rawdata.txt
# BAD FILE (FILENAME) bkg49_chamber49_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err4_108_chamber21_2018_04_24_rawdata.txt
# BAD FILE (FILENAME) Al16_chamber8_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) GtBent04_chamber4_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) STO2325_chamber6_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) bkg33_chamber33_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent22_chamber22_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) bkg5_chamber5_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) empty37_rawdata.txt
# BAD FILE (FILENAME) GtBent01_chamber1_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) bkg16_chamber16_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err5_092_chamber6_2018_04_12_rawdata.txt
# BAD FILE (FILENAME) err3_046_chamber25_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) GtBent10_chamber35_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) STO2337_chamber18_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) STO2320_chamber1_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) empty47_rawdata.txt
# BAD FILE (FILENAME) err1_062_chamber27_2018_05_04_rawdata.txt
# BAD FILE (FILENAME) 15_chamber15_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) GtBent13_chamber38_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) STO2341_chamber22_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) err5_064_chamber44_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) al5_chamber4_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) AlS_chamber20_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) al8_chamber7_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) GtBent14_chamber39_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) GtBent19_chamber19_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) bkg26_chamber26_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) Example2_chamber14_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) err4_067_chamber46_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) bkg48_2_chamber48_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) GtBent03_chamber3_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) err5_082_chamber31_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) GtBent15_chamber15_2018_04_09_rawdata - Copy.txt
# BAD FILE (FILENAME) STO2335_chamber16_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) STO2322_chamber3_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) bkg7_chamber7_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) bkg13_chamber13_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) al18_chamber17_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) err4_101_chamber14_2018_04_19_rawdata.txt
# BAD FILE (FILENAME) al14_chamber13_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) err2_047_chamber28_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) empty30_rawdata.txt
# BAD FILE (FILENAME) err5_085_chamber31_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) GtBent06_chamber6_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) bkg36_chamber36_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err2_064_chamber28_2018_05_10_rawdata.txt
# BAD FILE (FILENAME) al13_chamber12_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) empty40_rawdata.txt
# BAD FILE (FILENAME) err1_043_chamber27_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) err1_051_chamber27_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) err5_102_chamber16_2018_04_19_rawdata.txt
# BAD FILE (FILENAME) bkg30_3_chamber30_2018_03_28_rawdata.txt
# BAD FILE (FILENAME) err3_059_chamber25_2018_04_30_rawdata.txt
# BAD FILE (FILENAME) GtBent17_chamber17_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) bkg23_chamber23_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) STO2329_chamber10_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) bkg18_2_chamber18_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) test_chamber27_2018_05_02_rawdata.txt
# BAD FILE (FILENAME) al7_chamber6_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) empty8_rawdata.txt
# BAD FILE (FILENAME) Al21_chamber1_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg7_2_chamber7_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) al23_chamber22_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) GtBent11_chamber36_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) err1_050_chamber27_2018_04_12_rawdata.txt
# BAD FILE (FILENAME) testR3_1_chamber10_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) err3_053_chamber25_2018_04_19_rawdata.txt
# BAD FILE (FILENAME) bkg33_2_chamber33_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) err3_049_chamber25_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) Retest03_chamber0_2018_04_24_rawdata.txt
# BAD FILE (FILENAME) empty17_rawdata.txt
# BAD FILE (FILENAME) bkg35_3_chamber35_2018_03_29_rawdata.txt
# BAD FILE (FILENAME) GtBent20_chamber20_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) err2_045_chamber28_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) GtBent11_chamber11_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) empty49_rawdata.txt
# BAD FILE (FILENAME) err5_075_chamber31_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) err1_058_chamber27_2018_04_30_rawdata.txt
# BAD FILE (FILENAME) GtBent13_chamber13_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) al1_chamber0_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) err5_103_chamber17_2018_04_20_rawdata.txt
# BAD FILE (FILENAME) GtBent12_chamber37_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) empty39_rawdata.txt
# BAD FILE (FILENAME) GtBent18_chamber18_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) Al19_chamber4_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg39_chamber39_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) bkg1_chamber1_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err1_054_chamber27_2018_04_20_rawdata.txt
# BAD FILE (FILENAME) err5_073_chamber30_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) empty25_rawdata.txt
# BAD FILE (FILENAME) STO2336_chamber17_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) GtBent05_chamber5_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) err5_094_chamber8_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) err4_102_chamber15_2018_04_19_rawdata.txt
# BAD FILE (FILENAME) bkg43_chamber43_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) STO2324_chamber5_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) bkg14_2_chamber14_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) Al59_chamber9_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg22_2_chamber22_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) GtBent23_chamber23_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) err2_048_chamber28_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) Al100_chamber10_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) empty1_rawdata.txt
# BAD FILE (FILENAME) bkg47_2_chamber47_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) Retest07_chamber2_2018_04_20_rawdata.txt
# BAD FILE (FILENAME) STO2321_chamber2_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) bkg47_chamber47_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) bkg46_2_chamber46_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) Al70_chamber20_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) STJ0210_ch30_2018_08_21_rawdata.txt
# BAD FILE (FILENAME) STO2332_chamber13_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) bkg23_2_chamber23_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) testing6_chamber45_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) err3_048_chamber25_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) bkg15_2_chamber15_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) err5_089_chamber3_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) GtBent09_chamber9_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) empty12_rawdata.txt
# BAD FILE (FILENAME) err5_072_chamber28_2018_04_01_rawdata.txt
# BAD FILE (FILENAME) bkg18_chamber18_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err4_076_chamber30_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) AlBlank_chamber22_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) empty4_rawdata.txt
# BAD FILE (FILENAME) bkg26_4_chamber26_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) err3_045_chamber25_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) err5_099_chamber13_2018_04_18_rawdata.txt
# BAD FILE (FILENAME) bkg34_3_chamber34_2018_03_29_rawdata.txt
# BAD FILE (FILENAME) bkg32_2_chamber32_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) GtBent17_chamber17_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) err2_053_chamber28_2018_04_19_rawdata.txt
# BAD FILE (FILENAME) err4_069_chamber48_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) err2_049_chamber28_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) bkg28_chamber28_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent24_chamber24_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) empty20_rawdata.txt
# BAD FILE (FILENAME) 1in_sand_chamber25_2018_04_16_rawdata.txt
# BAD FILE (FILENAME) bkg27_chamber27_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) empty45_rawdata.txt
# BAD FILE (FILENAME) GtBent06_chamber6_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) Al57_chamber8_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg19_2_chamber19_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) GtBent18_chamber18_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) empty35_rawdata.txt
# BAD FILE (FILENAME) err5_104_chamber18_2018_04_20_rawdata.txt
# BAD FILE (FILENAME) al4_chamber3_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) err5_065_chamber45_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) bkg6_2_chamber6_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) Retest04_chamber1_2018_04_23_rawdata.txt
# BAD FILE (FILENAME) bkg31_3_chamber31_2018_03_28_rawdata.txt
# BAD FILE (FILENAME) Retest01_chamber4_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) err5_086_chamber31_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) err2_061_chamber28_2018_05_01_rawdata.txt
# BAD FILE (FILENAME) err3_047_chamber25_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) bkg17_chamber17_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent09_chamber9_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) STO2339_chamber20_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) bkg26_5_chamber26_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) err3_064_chamber25_2018_05_10_rawdata.txt
# BAD FILE (FILENAME) STO2331_chamber12_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) testing4_chamber10_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) GtBent23_chamber23_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) err5_070_chamber25_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) err4_080_chamber30_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) empty29_rawdata.txt
# BAD FILE (FILENAME) bkg32_chamber32_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) al17_chamber16_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) bkg48_chamber48_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBEnt05_chamber5_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) testing2_chamber45_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) err4_088_chamber1_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) stxxxxxx_chamber29_2018_05_01_rawdata.txt
# BAD FILE (FILENAME) err3_052_chamber25_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) bkg4_2_chamber4_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) err4_062_chamber41_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) Al7_chamber16_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) Retest04_chamber2_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) err4_103_chamber16_2018_04_20_rawdata.txt
# BAD FILE (FILENAME) err1_056_chamber27_2018_04_24_rawdata.txt
# BAD FILE (FILENAME) bkg35_2_chamber35_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) err4_075_chamber30_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) al 2_chamber1_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) bkg33_3_chamber33_2018_03_29_rawdata.txt
# BAD FILE (FILENAME) Al51_chamber2_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) err2_055_chamber28_2018_04_23_rawdata.txt
# BAD FILE (FILENAME) Al12_chamber13_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) err4_104_chamber17_2018_04_20_rawdata.txt
# BAD FILE (FILENAME) GtBent10_chamber10_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) _chamber0_2018_10_02_rawdata.txt
# BAD FILE (FILENAME) err5_078_chamber32_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) Al54_chamber5_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) Retest06_chamber2_2018_04_16_rawdata.txt
# BAD FILE (FILENAME) Al63_chamber13_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) GtBent23_chamber23_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) GtBent12_chamber12_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) err5_110_chamber24_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) bkg40_chamber40_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) Retest04_chamber1_2018_04_20_rawdata.txt
# BAD FILE (FILENAME) empty18_rawdata.txt
# BAD FILE (FILENAME) empty46_rawdata.txt
# BAD FILE (FILENAME) bkg12_2_chamber12_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) bkg24_2_chamber24_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) GtBent20_chamber20_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) bkg2_chamber2_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) bkg9_2_chamber9_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) empty36_rawdata.txt
# BAD FILE (FILENAME) err4_092_chamber5_2018_04_12_rawdata.txt
# BAD FILE (FILENAME) bkg41_2_chamber41_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) GtBent06_chamber6_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) GtBent05_chamber5_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) err4_091_chamber4_2018_04_12_rawdata.txt
# BAD FILE (FILENAME) bkg10_chamber10_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) Al64_chamber15_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) empty23_rawdata.txt
# BAD FILE (FILENAME) GtBent24_chamber24_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) err4_072_chamber27_2018_04_01_rawdata.txt
# BAD FILE (FILENAME) bkg39_2_chamber39_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) err4_085_chamber30_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) GtBent06_chamber6_2018_04_10_rawdata.txt
# BAD FILE (FILENAME) err5_101_chamber15_2018_04_19_rawdata.txt
# BAD FILE (FILENAME) err5_093_chamber7_2018_04_12_rawdata.txt
# BAD FILE (FILENAME) bkg35_chamber35_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) empty7_rawdata.txt
# BAD FILE (FILENAME) err4_082_chamber30_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) err2_044_chamber28_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) bkg27_3_chamber27_2018_03_28_rawdata.txt
# BAD FILE (FILENAME) err3_056_chamber25_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) bkg4_chamber4_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent07_chamber7_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) test31_chamber31_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) err1_046_chamber27_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) 15355_chamber30_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) empty11_rawdata.txt
# BAD FILE (FILENAME) Al22_chamber2_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg20_chamber20_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) Retest08_chamber9_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) bkg30_2_chamber30_2018_03_26_rawdata.txt
# BAD FILE (FILENAME) err4_078_chamber31_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) err5_062_chamber42_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) Al11_chamber12_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) Al52_chamber3_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) Retest08_chamber0_2018_04_16_rawdata.txt
# BAD FILE (FILENAME) Retest06_chamber5_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) err3_058_chamber25_2018_04_27_rawdata.txt
# BAD FILE (FILENAME) testing_chamber45_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) bkg29_2_chamber29_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) Al68_chamber18_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) empty2_rawdata.txt
# BAD FILE (FILENAME) Retest07_chamber2_2018_04_23_rawdata.txt
# BAD FILE (FILENAME) err4_096_chamber9_2018_04_16_rawdata.txt
# BAD FILE (FILENAME) err4_065_chamber44_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) bkg24_chamber24_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) al20_chamber19_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) err1_060_chamber27_2018_05_02_rawdata.txt
# BAD FILE (FILENAME) Retest03_chamber2_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) Al24_chamber0_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) empty26_rawdata.txt
# BAD FILE (FILENAME) bkg31_2_chamber31_2018_03_26_rawdata.txt
# BAD FILE (FILENAME) err5_066_chamber46_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) GtBent05_chamber5_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) GtBent20_chamber20_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) GtBent18_chamber18_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) err3_044_chamber25_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) GtBent12_chamber37_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) GtBent06_chamber6_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) bkg14_chamber14_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) err1_061_chamber27_2018_05_03_rawdata.txt
# BAD FILE (FILENAME) Retest02_chamber29_2018_04_27_rawdata.txt
# BAD FILE (FILENAME) err5_080_chamber31_2018_04_04_rawdata.txt
# BAD FILE (FILENAME) bkg38_2_chamber38_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) bkg31_chamber31_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) STO2327_chamber8_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) Retest2_chamber29_2018_04_30_rawdata.txt
# BAD FILE (FILENAME) err4_086_chamber30_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) empty14_rawdata.txt
# BAD FILE (FILENAME) err5_076_chamber31_2018_04_03_rawdata.txt
# BAD FILE (FILENAME) bkg40_2_chamber40_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) bkg9_chamber9_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) GtBent11_chamber36_2018_04_05_rawdata.txt
# BAD FILE (FILENAME) Al17_chamber7_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) bkg44_chamber44_2018_03_23_rawdata.txt
# BAD FILE (FILENAME) bkg13_2_chamber13_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) GtBent17_chamber17_2018_04_06_rawdata.txt
# BAD FILE (FILENAME) err4_087_chamber0_2018_04_10_rawdata.txt
# BAD FILE (FILENAME) Retest02_chamber3_2018_04_20_rawdata.txt
# BAD FILE (FILENAME) GtBent24_chamber24_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) bkg8_2_chamber8_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) al10_chamber9_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) err3_055_chamber25_2018_04_23_rawdata.txt
# BAD FILE (FILENAME) err3_061_chamber25_2018_05_02_rawdata.txt
# BAD FILE (FILENAME) empty33_rawdata.txt
# BAD FILE (FILENAME) err5_069_chamber49_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) testing7_chamber14_2018_04_02_rawdata.txt
# BAD FILE (FILENAME) empty43_rawdata.txt
# BAD FILE (FILENAME) bkg5_2_chamber5_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) err4_066_chamber45_2018_03_31_rawdata.txt
# BAD FILE (FILENAME) Al67_chamber17_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) err4_099_chamber12_2018_04_18_rawdata.txt
# BAD FILE (FILENAME) STO2340_chamber21_2018_08_28_rawdata.txt
# BAD FILE (FILENAME) err2_052_chamber28_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) err4_095_chamber8_2018_04_16_rawdata.txt
# BAD FILE (FILENAME) err5_090_chamber4_2018_04_11_rawdata.txt
# BAD FILE (FILENAME) err4_110_chamber23_2018_04_25_rawdata.txt
# BAD FILE (FILENAME) bkg34_2_chamber34_2018_03_27_rawdata.txt
# BAD FILE (FILENAME) Retest02_chamber0_2018_04_17_rawdata.txt
# BAD FILE (FILENAME) GtBent14_chamber14_2018_04_09_rawdata.txt
# BAD FILE (FILENAME) Retest05_chamber4_2018_04_13_rawdata.txt
# BAD FILE (FILENAME) Al8_chamber17_2018_07_02_rawdata.txt
# BAD FILE (FILENAME) al9_chamber8_2018_07_06_rawdata.txt
# BAD FILE (FILENAME) ST5286_chamber11_2021_03_05_rawdata.txt
# BAD FILE (VALUE) ST24897_chamber20_2022_01_28_rawdata.txt
# BAD FILE (FILENAME) ST4163_chamber15_2021_06_17_rawdata.txt
# BAD FILE (FILENAME) ST0009_chamber8_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0010_chamber9_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0004_chamber3_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0015_chamber14_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0016_chamber15_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0012_chamber11_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0001_chamber0_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0007_chamber6_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0011_chamber10_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0002_chamber1_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0008_chamber7_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0005_chamber4_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0006_chamber5_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0003_chamber2_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0014_chamber13_2019_05_16_rawdata.txt
# BAD FILE (FILENAME) ST0013_chamber12_2019_05_16_rawdata.txt
# BAD FILE (VALUE) ST17028_chamber11_2021_06_25_rawdata.txt
# BAD FILE (VALUE) ST99005_chamber24_2021_06_25_rawdata.txt
# BAD FILE (VALUE) ST99002_chamber9_2021_06_25_rawdata.txt
# BAD FILE (FILENAME) ST1541_chamber7_2021_03_05_rawdata.txt

# %%
leak_df = pd.DataFrame(leak_data)
leak_df['status'] = leak_df['status'].apply(lambda x: x.value)
leak_df
# Out:
#        straw                            leak_data_file      rate  \
# 0      11163   ST11163_chamber1_2019_08_29_rawdata.txt  0.030628
# 1      11473   ST11473_chamber0_2019_09_04_rawdata.txt  0.000042
# 2      10869  ST10869_chamber49_2019_08_26_rawdata.txt  0.000030
# 3      11830  ST11830_chamber24_2019_09_12_rawdata.txt  0.000063
# 4      11874  ST11874_chamber22_2019_09_13_rawdata.txt  0.000075
# ...      ...                                       ...       ...
# 32405  14992  ST14992_chamber11_2021_04_20_rawdata.txt  0.001840
# 32406  14319  ST14319_chamber15_2021_04_28_rawdata.txt  0.000056
# 32407  14495   ST14495_chamber4_2022_06_01_rawdata.txt  0.000062
# 32408  14032   ST14032_chamber1_2020_03_06_rawdata.txt  0.000059
# 32409  14379   ST14379_chamber3_2021_04_09_rawdata.txt  0.000062
#
#                  rate_err status  chamber
# 0      0.001737+0.000000j      U        1
# 1      0.000009+0.000000j      P        0
# 2      0.000007+0.000000j      P       49
# 3      0.000010+0.000000j      U       24
# 4      0.000007+0.000000j      P       22
# ...                   ...    ...      ...
# 32405  0.000068+0.000000j      F       11
# 32406  0.000001+0.000000j      P       15
# 32407  0.000003+0.000000j      P        4
# 32408  0.000009+0.000000j      P        1
# 32409  0.000003+0.000000j      P        3
#
# [32410 rows x 6 columns]

# %%
# save all rates to csv for chamber analysis
leak_df.drop(leak_df[ leak_df['status'] == "U"].index , inplace=True)
leak_df.to_csv("all_leak_tests_2022-06.csv")
leak_df
# Out:
#        straw                            leak_data_file      rate  \
# 1      11473   ST11473_chamber0_2019_09_04_rawdata.txt  0.000042
# 2      10869  ST10869_chamber49_2019_08_26_rawdata.txt  0.000030
# 4      11874  ST11874_chamber22_2019_09_13_rawdata.txt  0.000075
# 6      10547  ST10547_chamber37_2019_08_22_rawdata.txt  0.000077
# 7      10268   ST10268_chamber7_2019_08_20_rawdata.txt  0.000093
# ...      ...                                       ...       ...
# 32405  14992  ST14992_chamber11_2021_04_20_rawdata.txt  0.001840
# 32406  14319  ST14319_chamber15_2021_04_28_rawdata.txt  0.000056
# 32407  14495   ST14495_chamber4_2022_06_01_rawdata.txt  0.000062
# 32408  14032   ST14032_chamber1_2020_03_06_rawdata.txt  0.000059
# 32409  14379   ST14379_chamber3_2021_04_09_rawdata.txt  0.000062
#
#                  rate_err status  chamber
# 1      0.000009+0.000000j      P        0
# 2      0.000007+0.000000j      P       49
# 4      0.000007+0.000000j      P       22
# 6      0.000006+0.000000j      P       37
# 7      0.000005+0.000000j      P        7
# ...                   ...    ...      ...
# 32405  0.000068+0.000000j      F       11
# 32406  0.000001+0.000000j      P       15
# 32407  0.000003+0.000000j      P        4
# 32408  0.000009+0.000000j      P        1
# 32409  0.000003+0.000000j      P        3
#
# [28286 rows x 6 columns]

# %%
# remove lines with negative leak values
leak_df.drop(leak_df[ leak_df['rate'] <= 0 ].index , inplace=True)

#leak_df = leak_df.rename_axis(None)

# remove failed, unknown tests
leak_df.drop(leak_df[ leak_df['status'] == "F"].index , inplace=True)
leak_df.drop(leak_df[ leak_df['status'] == "U"].index , inplace=True)
leak_df
# Out:
#        straw                            leak_data_file      rate  \
# 1      11473   ST11473_chamber0_2019_09_04_rawdata.txt  0.000042
# 2      10869  ST10869_chamber49_2019_08_26_rawdata.txt  0.000030
# 4      11874  ST11874_chamber22_2019_09_13_rawdata.txt  0.000075
# 6      10547  ST10547_chamber37_2019_08_22_rawdata.txt  0.000077
# 7      10268   ST10268_chamber7_2019_08_20_rawdata.txt  0.000093
# ...      ...                                       ...       ...
# 32404  14304  ST14304_chamber13_2021_04_07_rawdata.txt  0.000078
# 32406  14319  ST14319_chamber15_2021_04_28_rawdata.txt  0.000056
# 32407  14495   ST14495_chamber4_2022_06_01_rawdata.txt  0.000062
# 32408  14032   ST14032_chamber1_2020_03_06_rawdata.txt  0.000059
# 32409  14379   ST14379_chamber3_2021_04_09_rawdata.txt  0.000062
#
#                  rate_err status  chamber
# 1      0.000009+0.000000j      P        0
# 2      0.000007+0.000000j      P       49
# 4      0.000007+0.000000j      P       22
# 6      0.000006+0.000000j      P       37
# 7      0.000005+0.000000j      P        7
# ...                   ...    ...      ...
# 32404  0.000005+0.000000j      P       13
# 32406  0.000001+0.000000j      P       15
# 32407  0.000003+0.000000j      P        4
# 32408  0.000009+0.000000j      P        1
# 32409  0.000003+0.000000j      P        3
#
# [22190 rows x 6 columns]

# %%
# Keep one test/rate per file
# Na, don't do this any more. We can do it in the analysis.

# show straws with multiple tests
#straw_df = straw_df.rename_axis(None)
#straw_df[straw_df.straw.duplicated(keep=False)].sort_values(by=['straw'])

# only keep the tests with the smallest leaks
# straw_df = straw_df.groupby('straw', group_keys=False).apply(lambda x: x.loc[x.rate.idxmin()])

# show that we've removed all but the smallest rates
#straw_df[straw_df.straw.duplicated(keep=False)].sort_values(by=['straw']) # throwing error. maybe no duplicates.

#straw_df.sort_values(by=['straw'])

# %% [markdown]
# ## 2. Panel, batch, and PPG info

# %%
# organized by their panel; includes batch, position number
#straw_list_file = Path("straws_on_panels.csv")
#straw_list_file = Path("2022-04-07_straws_on_panels.csv")
#straw_list_file = Path("2022-04-15_straws_on_panels.csv") # include paper pull grade
straws_on_panels_file = Path("2022-06-16_straws_on_panels.csv") # extends data up to MN244
assert straws_on_panels_file.is_file()

db_df = pd.read_csv(straws_on_panels_file, sep=",")
db_df.columns = db_df.columns.str.replace(" ", "")
db_df = db_df.rename(columns={"id": "straw"})

# %% [markdown]
# ## Combine data

# %%
# add leak info to every straw that has an associated panel
straws_on_panels_df = db_df.merge(leak_df, on=['straw'], how = 'left')
straws_on_panels_df

# %%
# add panel info to every leak test
all_straws_df = leak_df.merge(db_df, on=['straw'], how = 'left')
all_straws_df

# %% [markdown]
# ## Make csvs

# %%
straws_on_panels_df.to_csv("straws_on_panels_MN173_MN244.csv")
all_straws_df.to_csv("all_straws_2022-06-13.csv")

# %%
leak_df.to_csv("all_passing_leak_tests_2022-06.csv")
